# %% [markdown]
# # Evoastra Ventures Intern Assessment Task
# **Duration: 35 Minutes | Total Points: 100**
#
# ---

# %% [markdown]
# ## **Candidate Information**
#
# **Fill in your details below:**
# - **Name:** Niti Budania
# - **Email:** nitibudania@gmail.com
# - **Phone:** +91 9429681070
# - **College/University:** Nirma University
# - **Course/Branch:** Electronics and Communication
# - **Start Time:** 11:45AM
# - **End Time:** 12:15PM

# %% [markdown]
# ## **Dataset for Assessment**
#
# **E-commerce Customer Behavior Dataset**
# - **Direct Link:** https://www.kaggle.com/datasets/shriyashjagtap/e-commerce-customer-for-behavior-analysis
#
# **Dataset Columns:**
# - **Customer ID:** Unique identifier for each customer
# - **Customer Name:** Name of the customer
# - **Customer Age:** Age of the customer
# - **Gender:** Gender of the customer
# - **Purchase Date:** Date of each purchase
# - **Product Category:** Category of the purchased product
# - **Product Price:** Price of the purchased product
# - **Quantity:** Quantity of product purchased
# - **Total Purchase Amount:** Total amount spent in each transaction
# - **Payment Method:** Payment method used (credit card, PayPal, etc.)
# - **Returns:** Whether customer returned products (0 = No, 1 = Yes)
# - **Churn:** Whether customer has churned (0 = Retained, 1 = Churned)

# %% [markdown]
# ---
# ## **SECTION A: Data Understanding & Basic Analysis (25 Points - 10 Minutes)**

# %% [markdown]
# ### Question 1 (8 points)
# Based on the dataset structure, identify the **data types** for the following columns and explain why each classification is important for analysis:
#
# - **Customer Age**
# - **Gender**
# - **Total Purchase Amount**
# - **Churn**

# %%
# Your Answer for Question Gender
Data Type: Categorical (Nominal)
Gender is a categorical variable with distinct labels such as Male and Female. This classification is important for demographic analysis, enabling comparison of customer behavior, product preferences, and payment choices across different gender groups.2
# a) ProduTotal Purchase Amount
Data Type: Numerical (Continuous)
Total Purchase Amount is a continuous numerical variable that represents the total monetary value of each transaction. It is crucial for revenue analysis, profitability measurement, customer value estimation, and business performance evaluation.ct categories with highest revenue:
# b) Predicting customer churn:
Churn
Data Type: Categorical (Binary)
Churn is a binary categorical variable where 0 indicates retained customers and 1 indicates churned customers. This variable is essential for retention analysis and predictive modeling to identify customers likely to leave the platform.

# %% [markdown]
# ### Question 2 (8 points)
# Which **analytical technique** would be most appropriate for each business question below?
#
# a) "Which product categories generate the highest revenue?"
# b) "Can we predict customer churn based on purchase behavior?"
# c) "What is the relationship between customer age and spending patterns?"
# d) "Which payment methods are preferred by different customer segments?"

# %%
a) Product categories with highest revenue

Analytical Technique:
Descriptive analysis using aggregation (group-by and sum of total purchase amount by product category).

b) Predicting customer churn

Analytical Technique:
Predictive analytics using classification models such as Logistic Regression, Decision Trees, or Random Forest.

c) Age and spending relationship

Analytical Technique:
Correlation analysis or regression analysis to study the relationship between customer age and total spending.

d) Payment method preferences

Analytical Technique:
Segmentation analysis using cross-tabulation or frequency analysis of payment methods across customer segments.

# %% [markdown]
# ### Question 3 (9 points)
# **Data Quality Assessment:** What are the top 3 potential data quality issues you would check for in this e-commerce dataset before starting analysis? For each issue, suggest one method to detect it.

# %%
Issue 1: Missing or Null Values
Detection Method:
Check for missing values using null value counts and summary statistics for each column.

Issue 2: Duplicate Records
Detection Method:
Identify duplicate rows using combinations of Customer ID, Purchase Date, and Product Category.

Issue 3: Inconsistent or Invalid Data Values
Detection Method:
Validate data ranges and data types (e.g., negative purchase amounts, unrealistic ages) using descriptive statistics and data validation checks.

# %% [markdown]
# ---
# ## **SECTION B: Customer Analysis & Business Intelligence (35 Points - 15 Minutes)**

# %% [markdown]
# ### Scenario: E-commerce Revenue Analysis
#
# Based on the dataset structure, assume you have the following customer insights:
#
# **Customer Segments by Age:**
# - **Young (18-30):** 40% of customers, Average Purchase Amount: ₹850, Return Rate: 12%
# - **Middle-aged (31-50):** 45% of customers, Average Purchase Amount: ₹1,200, Return Rate: 8%
# - **Senior (51+):** 15% of customers, Average Purchase Amount: ₹950, Return Rate: 15%
#
# **Additional Information:**
# - Average customer acquisition cost: ₹180
# - Platform profit margin: 20% of purchase amount
# - Customer churn rates: Young (25%), Middle-aged (15%), Senior (30%)

# %% [markdown]
# ### Question 4 (15 points)
# **Calculate and analyze:**
#
# a) Which customer segment generates the highest **net profit per customer** (considering returns)? Show your calculations. (8 points)
#
# b) Which segment has the **best customer lifetime value** considering churn rates? Provide reasoning. (7 points)

# %%
# Your Calculations for Question 4

# a) Net profit per customer calculations:
The Middle-aged customer segment generates the highest net profit per customer at ₹40.8, 
while Young and Senior segments currently result in a net loss.
# Young Customers:

# Middle-aged Customers:

# Senior Customers:

# b) Customer Lifetime Value Analysis:
The Middle-aged segment has the best customer lifetime value due to higher profitability per transaction 
and significantly lower churn, making them the most valuable long-term customers.

# %% [markdown]
# ### Question 5 (10 points)
# **Strategic Recommendations:** Based on your analysis, what would be your **top 2 marketing strategies** to maximize overall profitability? Consider customer acquisition, retention, and return rates.

# %%
# Your Answer for Question 5

# Strategy 1:
Strategy 1: Focus Retention Campaigns on Middle-aged Customers

Prioritize loyalty programs, personalized offers, 
and premium memberships for middle-aged customers to maximize lifetime value and maintain low churn.


# Strategy 2:
Strategy 2: Reduce Returns in Young and Senior Segments

Improve product descriptions, sizing guides, and post-purchase support to lower return rates,
thereby improving profitability for Young and Senior customer segments.

# %% [markdown]
# ### Question 6 (10 points)
# **Churn Prevention:** You notice that customers who make purchases in the "Electronics" category have a 35% churn rate, while "Fashion" category customers have only 18% churn rate. What **specific data analysis** would you conduct using the available dataset columns to understand this difference, and what **action plan** would you recommend?

# %%
# Your Answer for Question 6
Data Analysis Plan
Compare churn rates across product categories using Customer ID and Product Category.
Analyze return rates, total purchase amount, and payment method for Electronics vs Fashion customers.
Segment Electronics buyers by age, purchase frequency, and returns to identify high-risk churn patterns.

Action Plan
Introduce extended warranties, better customer support, and follow-up engagement for Electronics customers.
Offer incentives such as discounts on next purchase after Electronics transactions.
Apply Fashion-style retention strategies (e.g., personalization) to Electronics customers to reduce churn.

# %% [markdown]
# ---
# ## **SECTION C: Research Methodology & Predictive Analytics (25 Points - 8 Minutes)**

# %% [markdown]
# ### Scenario: Churn Prediction Model Development
#
# Your company wants to build a machine learning model to predict customer churn using the available dataset.

# %% [markdown]
# ### Question 7 (15 points)
# **Model Development Plan:** Create a comprehensive approach including:
#
# a) **Feature selection:** Which columns from the dataset would you use as features for the churn prediction model and why? (5 points)
# b) **Data preprocessing steps:** What preprocessing would you apply to prepare the data? (5 points)
# c) **Model evaluation metrics:** Which metrics would you use to evaluate model performance for this business problem? (5 points)

# %%
# Your Answer for Question 7

# a) Feature Selection:
a) Feature Selection

The following columns would be used as features for the churn prediction model:
Customer Age: Helps capture life-stage behavior and spending patterns.
Gender: Useful for demographic-based behavior differences.
Product Category: Indicates customer interest areas and risk-prone categories.
Product Price & Quantity: Reflect purchase value and buying intensity.
Total Purchase Amount: Strong indicator of customer value and engagement.
Payment Method: May influence trust, convenience, and retention behavior.
Returns: High returns often correlate with dissatisfaction and churn.
These features collectively capture customer demographics, purchase behavior, and satisfaction levels,
which are critical for predicting churn.
# b) Data Preprocessing Steps:
b) Data Preprocessing Steps

The following preprocessing steps would be applied:
Handling Missing Values: Impute numerical variables using mean/median and categorical variables using mode.
Encoding Categorical Variables: Convert Gender, Product Category, and Payment Method using one-hot encoding
or label encoding.
Outlier Detection: Identify extreme values in purchase amount and quantity using IQR or z-score methods.
Feature Scaling: Apply normalization or standardization to numerical features for model stability.
Train-Test Split: Split data into training and testing sets to evaluate generalization.
# c) Model Evaluation Metrics:
c) Model Evaluation Metrics

The following metrics would be used to evaluate churn prediction performance:
Accuracy: Overall correctness of predictions.
Precision: Measures how many predicted churners actually churned.
Recall: Measures how many actual churners were correctly identified.
F1-score: Balances precision and recall, especially important for imbalanced churn data.
ROC-AUC: Evaluates model’s ability to distinguish between churned and retained customers.

# %% [markdown]
# ### Question 8 (10 points)
# **Business Impact Analysis:** Identify 3 potential business challenges in implementing a churn prediction model and propose one **data-driven solution** for each challenge using insights from the customer behavior dataset.

# %%
# Your Answer for Question 8

# Challenge 1:
# Data-driven Solution 1:
Challenge 1: Class Imbalance in Churn Data
Churned customers may represent a smaller portion of the dataset.
Data-driven Solution:
Apply techniques such as oversampling (SMOTE) or class-weighted models to ensure churners are properly learned by the model.
# Challenge 2:
# Data-driven Solution 2:
Challenge 2: Translating Predictions into Business Actions
Predicted churn scores may not directly lead to actionable decisions.
Data-driven Solution:
Segment customers based on churn probability and create targeted retention strategies such as
personalized discounts or proactive support.
# Challenge 3:
# Data-driven Solution 3:
Challenge 3: Model Interpretability for Stakeholders
Complex models may be difficult for non-technical teams to trust.
Data-driven Solution:
Use interpretable models like Logistic Regression or apply explainability techniques such as 
feature importance and SHAP values to communicate insights clearly.

# %% [markdown]
# ---
# ## **SECTION D: Professional Communication & Problem-Solving (15 Points - 2 Minutes)**

# %% [markdown]
# ### Question 9 (8 points)
# **Crisis Management:** While analyzing the dataset, you discover that 40% of customers who returned products (Returns = 1) also churned within the same month. However, your initial analysis showed returns don't strongly correlate with churn. As a team member, describe your immediate approach to investigate this discrepancy and communicate findings to stakeholders (60-80 words).

# %%
Upon identifying the discrepancy, I would first validate the finding by performing time-based and
category-level churn analysis for returned products. 
I would investigate whether churn increases immediately after returns rather than overall correlation. 
I would then communicate these insights clearly to stakeholders, explaining the short-term churn risk 
associated with returns and proposing targeted post-return engagement strategies to reduce customer attrition.

# %% [markdown]
# ### Question 10 (7 points)
# **Leadership Scenario:** If selected as team lead for analyzing this e-commerce customer dataset, what would be your **top 3 priorities** to ensure effective team collaboration and delivery of actionable business insights?

# %%
# Your Answer for Question 10

# Priority 1:
Priority 1: Clear Task Ownership and Timelines

Define roles, responsibilities, and deadlines early to ensure smooth collaboration and timely delivery of insights.
# Priority 2:
Priority 2: Data Quality and Analytical Consistency

Ensure all team members follow standardized data cleaning, analysis, and documentation practices to maintain accuracy
and reliability.
# Priority 3:
Priority 3: Business-Focused Communication

Translate technical findings into clear business insights and actionable recommendations for stakeholders.

# %% [markdown]
# ---
# ## **Self-Assessment Section**

# %%
# Time Management Check
# Did you complete all sections within 35 minutes? (Yes/No):
YES
# Which section took the most time?
Section B (Customer Analysis & Business Intelligence), due to detailed calculations and business interpretation.
# Which section was most challenging?
Section C (Research Methodology & Predictive Analytics), as it required balancing technical modeling decisions
with business applicability.
# Confidence Level (1-10 scale):
# Section A (Data Understanding):
Section A (Data Understanding): 9
# Section B (Business Analysis):
Section B (Business Analysis): 9
# Section C (Research Methodology):
Section C (Research Methodology): 8
# Section D (Communication):
Section D (Communication): 9
# Additional Comments:
This assessment strengthened my ability to translate data analysis into actionable business insights. 
I focused on clarity, structured thinking, and stakeholder-oriented communication while working under time constraints,
similar to real-world analytics projects.

# %% [markdown]
# ---
# ## **Submission Instructions**
#
# 1. **Save this notebook** with the filename: `YourName_Evoastra_Assessment.ipynb`
# 2. **Ensure all code cells have been executed** and answers are visible
# 3. **Double-check** that all sections are completed
#
# **Submission Confirmation:**
# - I confirm that I have completed this assessment independently
# - All my responses are my own original work
#
# **Digital Signature:** Niti Budania
#
# **Final Submission Time:** 18 Dec 2025, 1 PM IST

# %% [markdown]
# ---
# ## **Evaluation Criteria**
#
# **Scoring Breakdown:**
# - **Section A (Data Understanding):** 25 points
# - **Section B (Business Analysis):** 35 points
# - **Section C (Research Methodology):** 25 points
# - **Section D (Communication):** 15 points
# - **Total:** 100 points
#
# **Team Selection Criteria:**
# - **Team Lead:** Score ≥ 75 points + Strong Section D performance
# - **Co-Lead:** Score ≥ 65 points + Good Section D performance
# - **Team Member:** Successful completion of assessment
#
# ---
#
# *Good luck with your assessment! Focus on clear reasoning, accurate calculations, and practical business applications.*
